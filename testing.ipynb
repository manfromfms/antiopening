# %%
import nnue_parser

# Initialize the NNUE model (adjust the path to your NNUE file)
nnue_parser.init_nnue_py("./nn-46832cfbead3.nnue")

# Example FEN string for the starting chess position
fen = "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1"

# Evaluate the position in centipawns
evaluation = nnue_parser.eval_nnue_py(fen)
print("Evaluation in centipawns:", evaluation)
# Out:
# Version: 2062757664
# Hash: 1007697522
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import nnue_parser
#       3 # Initialize the NNUE model (adjust the path to your NNUE file)
# ----> 4 nnue_parser.init_nnue_py("./nn-46832cfbead3.nnue")
#       6 # Example FEN string for the starting chess position
#       7 fen = "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1"
#
# ValueError: Es wurden nicht alle Parameter gelesen!
